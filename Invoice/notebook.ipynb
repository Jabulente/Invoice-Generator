# %%
import os
from data_generator import generate_dataset
from utils import save_to_csv, log_success
from pdf_invoice import PDFInvoice

# %%
if __name__ == "__main__":
    df = generate_dataset(num_customers=5, min_items=1, max_items=5)
    os.makedirs("datasets", exist_ok=True)
    filepath = "datasets/orders.csv"
    df.to_csv(filepath, index=False)
    display(df)
# Out:
#      customer_name           customer_email         customer_phone  \
# 0      Hunter Shah     huntershah@gmail.com       001-752-894-8617
# 1   Russell Garcia  russellgarcia@gmail.com          (575)297-6839
# 2   Russell Garcia  russellgarcia@gmail.com          (575)297-6839
# 3   Russell Garcia  russellgarcia@gmail.com          (575)297-6839
# 4       Sean Lopez      seanlopez@gmail.com  001-582-549-3235x4860
# 5       Sean Lopez      seanlopez@gmail.com  001-582-549-3235x4860
# 6       Sean Lopez      seanlopez@gmail.com  001-582-549-3235x4860
# 7       Sean Lopez      seanlopez@gmail.com  001-582-549-3235x4860
# 8       Sean Lopez      seanlopez@gmail.com  001-582-549-3235x4860
# 9        Drew King       drewking@gmail.com     638.815.1472x42146
# 10       Drew King       drewking@gmail.com     638.815.1472x42146
# 11       Drew King       drewking@gmail.com     638.815.1472x42146
# 12       Drew King       drewking@gmail.com     638.815.1472x42146
# 13  Kevin Hamilton  kevinhamilton@gmail.com           490.852.5879
# 14  Kevin Hamilton  kevinhamilton@gmail.com           490.852.5879
#
#                                      customer_address     cart_id  \
# 0          988 Robert Mountain, Raymondstad, MP 79262  INV-156094
# 1       7867 Danielle Passage, Higginsville, MS 92684  INV-511049
# 2       7867 Danielle Passage, Higginsville, MS 92684  INV-511049
# 3       7867 Danielle Passage, Higginsville, MS 92684  INV-511049
# 4   49933 Bass Junction Apt. 607, Port Catherine, ...  INV-945799
# 5   49933 Bass Junction Apt. 607, Port Catherine, ...  INV-945799
# 6   49933 Bass Junction Apt. 607, Port Catherine, ...  INV-945799
# 7   49933 Bass Junction Apt. 607, Port Catherine, ...  INV-945799
# 8   49933 Bass Junction Apt. 607, Port Catherine, ...  INV-945799
# 9    199 Gonzalez Land Suite 815, East Mark, WI 50137  INV-636204
# 10   199 Gonzalez Land Suite 815, East Mark, WI 50137  INV-636204
# 11   199 Gonzalez Land Suite 815, East Mark, WI 50137  INV-636204
# 12   199 Gonzalez Land Suite 815, East Mark, WI 50137  INV-636204
# 13          525 Michael Crest, North Steven, IN 25557  INV-645413
# 14          525 Michael Crest, North Steven, IN 25557  INV-645413
#
#                     description  quantity  unit_price  tax_rate  discount
# 0                   Logo Design         1         600       0.1      0.40
# 1              Training Session         2         250       0.1     14.45
# 2                   Logo Design         3         600       0.1      5.00
# 3               On-Site Support         2         500       0.1     13.77
# 4       IT Infrastructure Setup         1        2000       0.1     11.22
# 5              Training Session         2         250       0.1     13.36
# 6       IT Infrastructure Setup         1        2000       0.1     11.42
# 7       IT Infrastructure Setup         1        2000       0.1      9.09
# 8               SSL Certificate         3          75       0.1      7.29
# 9       IT Infrastructure Setup         2        2000       0.1      1.32
# 10             Training Session         3         250       0.1     12.43
# 11  Brand Strategy Consultation         1         950       0.1      0.28
# 12             Maintenance Plan         1         300       0.1      0.61
# 13              SSL Certificate         2          75       0.1      2.87
# 14             Maintenance Plan         2         300       0.1     13.92

# %% [markdown]
# # Generate invoices

# %%
if __name__ == "__main__":
    for cart_id, group in df.groupby('cart_id'):
        pdf = PDFInvoice(invoice_number=cart_id)
        pdf.add_page()
        
        customer = group.iloc[0]
        to_info = [
            customer['customer_name'],
            customer['customer_email'],
            customer['customer_phone'],
            customer['customer_address']
        ]
        
        from_info = [
            "Vertex",
            "support@vertexstore.com",
            "+255 123 456 789",
            "123 Commerce Street, Arusha, Tanzania"
        ]
    
        pdf.add_invoice_info(to_info, from_info)
        
        items = group.to_dict('records')
        subtotal = pdf.add_table(items)
        pdf.add_summary_section(subtotal)
        
        pdf_path = f"outputs/{cart_id}.pdf"
        pdf.output(pdf_path)
        log_success(pdf_path)
# Out:
# 2025-08-25 00:57:06 : outputs/INV-156094.pdf ------------------------------------------  Invoice Generated Successfully ✔
# 2025-08-25 00:57:06 : outputs/INV-511049.pdf ------------------------------------------  Invoice Generated Successfully ✔
# 2025-08-25 00:57:06 : outputs/INV-636204.pdf ------------------------------------------  Invoice Generated Successfully ✔
# 2025-08-25 00:57:06 : outputs/INV-645413.pdf ------------------------------------------  Invoice Generated Successfully ✔
# 2025-08-25 00:57:06 : outputs/INV-945799.pdf ------------------------------------------  Invoice Generated Successfully ✔
