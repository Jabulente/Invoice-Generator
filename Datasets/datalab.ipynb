# %% [markdown]
# <h2 style=' color: crimson;font-family: Colonna MT; font-weight: 600; font-size: 35px; text-align: Center'>Customer Dataset Generations </h2>
#
# ---

# %% [markdown]
# <h2 style='font-family: Colonna MT; font-weight: 600; font-size: 20px; text-align: left'>1.0. Import Required Libraries and Modules</h2>

# %%
from typing import List, Dict, Optional
from faker import Faker
import pandas as pd
import random

fake = Faker()

# %% [markdown]
# <h2 style='font-family: Colonna MT; font-weight: 600; font-size: 20px; text-align: left'>1.0. Class Construction </h2>

# %%
class DatasetGenerator:
    """
    A class to generate e-commerce dataset with customer and order information.
    """
    
    def __init__(self):
        self.products = [
            'Web Development', 'Maintenance Plan', 'SSL Certificate',
            'Brand Strategy Consultation', 'Logo Design', 
            'IT Infrastructure Setup', 'On-Site Support', 'Training Session'
        ]
        
        self.unit_prices = {
            'Web Development': 1200, 
            'Maintenance Plan': 300,
            'SSL Certificate': 75, 
            'Brand Strategy Consultation': 950,
            'Logo Design': 600, 
            'IT Infrastructure Setup': 2000,
            'On-Site Support': 500, 
            'Training Session': 250  
        }
        
        self.default_tax_rate = 0.1  # 10% tax
        
    def _generate_customer_info(self) -> Dict:
        """Generate basic customer information."""
        name = fake.name()
        return {
            'name': name,
            'email': f"{name.replace(' ', '').lower()}@gmail.com",
            'phone': fake.phone_number(),
            'address': fake.address().replace('\n', ', ')
        }
    
    def _generate_order_items(self, customer_name: str, num_items: int) -> List[Dict]:
        """Generate order items for a customer."""
        items = []
        cart_id = f"INV-{random.randint(100000, 999999)}"
        
        for _ in range(num_items):
            product = random.choice(self.products)
            quantity = random.randint(1, 3)
            unit_price = self.unit_prices[product]
            discount = round(random.uniform(0, 15), 2)  # Discount between 0% and 15%
            
            items.append({
                'cart_id': cart_id,
                'product_description': product,
                'quantity': quantity,
                'unit_price': unit_price,
                'tax_rate': self.default_tax_rate,
                'discount': discount
            })
        
        return items
    
    def generate_dataset(self, number_of_customers: int = 10, min_items: int = 1, max_items: int = 5) -> pd.DataFrame:
        """
        Generate a complete dataset with customer and order information.
        
        Args:
            number_of_customers: Number of customers to generate
            min_items: Minimum number of items per order
            max_items: Maximum number of items per order
            
        Returns:
            pandas.DataFrame: Generated dataset
        """
        data = []
        
        for _ in range(number_of_customers):
            customer = self._generate_customer_info()
            order_items = self._generate_order_items(
                customer['name'],
                random.randint(min_items, max_items)
            )
            
            for item in order_items:
                record = {
                    'customer_name': customer['name'],
                    'customer_email': customer['email'],
                    'customer_phone': customer['phone'],
                    'customer_address': customer['address'],
                    **item
                }
                data.append(record)
        
        return pd.DataFrame(data)
    
    def save_to_csv(self, df: pd.DataFrame, filename: str = "orders.csv") -> None:
        """Save the generated dataset to a CSV file."""
        df.to_csv(filename, index=False)
        print(f"Dataset saved to {filename}")

# %% [markdown]
# <h2 style='font-family: Colonna MT; font-weight: 600; font-size: 20px; text-align: left'>1.0. Datasets Generation and Saving </h2>

# %%
def main():
    # Initialize the generator
    generator = DatasetGenerator()
    
    # Generate dataset
    df = generator.generate_dataset(number_of_customers=10, min_items=1, max_items=5)
    
    # Display the dataset
    #print("Generated Dataset:")
    display(df)
    
    # Save to CSV
    generator.save_to_csv(df, "orders.csv")

if __name__ == "__main__":
    main()
# Out:
#            customer_name                 customer_email  \
# 0             Alex Rivas            alexrivas@gmail.com
# 1       Cheyenne Mcclain      cheyennemcclain@gmail.com
# 2       Cheyenne Mcclain      cheyennemcclain@gmail.com
# 3       Cheyenne Mcclain      cheyennemcclain@gmail.com
# 4       Steven Alexander      stevenalexander@gmail.com
# 5       Steven Alexander      stevenalexander@gmail.com
# 6             Gina Davis            ginadavis@gmail.com
# 7             Gina Davis            ginadavis@gmail.com
# 8           Scott Thomas          scottthomas@gmail.com
# 9           Scott Thomas          scottthomas@gmail.com
# 10          Scott Thomas          scottthomas@gmail.com
# 11         Molly Sellers         mollysellers@gmail.com
# 12         Molly Sellers         mollysellers@gmail.com
# 13         Molly Sellers         mollysellers@gmail.com
# 14         Molly Sellers         mollysellers@gmail.com
# 15         Molly Sellers         mollysellers@gmail.com
# 16          James Nguyen          jamesnguyen@gmail.com
# 17          James Nguyen          jamesnguyen@gmail.com
# 18          James Nguyen          jamesnguyen@gmail.com
# 19          James Nguyen          jamesnguyen@gmail.com
# 20  Catherine Mccullough  catherinemccullough@gmail.com
# 21  Catherine Mccullough  catherinemccullough@gmail.com
# 22  Catherine Mccullough  catherinemccullough@gmail.com
# 23  Catherine Mccullough  catherinemccullough@gmail.com
# 24  Catherine Mccullough  catherinemccullough@gmail.com
# 25          Tommy Jacobs          tommyjacobs@gmail.com
# 26          Tommy Jacobs          tommyjacobs@gmail.com
# 27          Tommy Jacobs          tommyjacobs@gmail.com
# 28            Tony Smith            tonysmith@gmail.com
# 29            Tony Smith            tonysmith@gmail.com
# 30            Tony Smith            tonysmith@gmail.com
# 31            Tony Smith            tonysmith@gmail.com
#
#            customer_phone                                   customer_address  \
# 0    001-536-950-0023x933        2781 Powers Ridge, East Elizabeth, ND 77262
# 1           (870)701-4141            2252 Walls Lodge, Danielville, ME 08856
# 2           (870)701-4141            2252 Walls Lodge, Danielville, ME 08856
# 3           (870)701-4141            2252 Walls Lodge, Danielville, ME 08856
# 4           (771)370-9337  260 Juan Shores Apt. 329, North Michaelburgh, ...
# 5           (771)370-9337  260 Juan Shores Apt. 329, North Michaelburgh, ...
# 6   +1-341-447-3476x67726  74008 Pamela Street Apt. 573, Skinnerberg, WI ...
# 7   +1-341-447-3476x67726  74008 Pamela Street Apt. 573, Skinnerberg, WI ...
# 8      866-791-2219x05914   349 Garza Islands Apt. 830, Danielport, CT 49857
# 9      866-791-2219x05914   349 Garza Islands Apt. 830, Danielport, CT 49857
# 10     866-791-2219x05914   349 Garza Islands Apt. 830, Danielport, CT 49857
# 11        +1-217-819-8392                         USNS Mathews, FPO AA 33841
# 12        +1-217-819-8392                         USNS Mathews, FPO AA 33841
# 13        +1-217-819-8392                         USNS Mathews, FPO AA 33841
# 14        +1-217-819-8392                         USNS Mathews, FPO AA 33841
# 15        +1-217-819-8392                         USNS Mathews, FPO AA 33841
# 16        +1-998-553-6337           93401 Chad Trail, Port William, KS 74819
# 17        +1-998-553-6337           93401 Chad Trail, Port William, KS 74819
# 18        +1-998-553-6337           93401 Chad Trail, Port William, KS 74819
# 19        +1-998-553-6337           93401 Chad Trail, Port William, KS 74819
# 20           217.741.3314       18340 Bryant Shores, New Scottfurt, HI 79484
# 21           217.741.3314       18340 Bryant Shores, New Scottfurt, HI 79484
# 22           217.741.3314       18340 Bryant Shores, New Scottfurt, HI 79484
# 23           217.741.3314       18340 Bryant Shores, New Scottfurt, HI 79484
# 24           217.741.3314       18340 Bryant Shores, New Scottfurt, HI 79484
# 25   +1-707-973-4109x0075            36942 Skinner Walk, Jaimeberg, NM 82163
# 26   +1-707-973-4109x0075            36942 Skinner Walk, Jaimeberg, NM 82163
# 27   +1-707-973-4109x0075            36942 Skinner Walk, Jaimeberg, NM 82163
# 28             3117612543     97984 Green Stream, Port Brandonland, GU 18127
# 29             3117612543     97984 Green Stream, Port Brandonland, GU 18127
# 30             3117612543     97984 Green Stream, Port Brandonland, GU 18127
# 31             3117612543     97984 Green Stream, Port Brandonland, GU 18127
#
#        cart_id          product_description  quantity  unit_price  tax_rate  \
# 0   INV-414607                  Logo Design         2         600       0.1
# 1   INV-349412             Maintenance Plan         3         300       0.1
# 2   INV-349412  Brand Strategy Consultation         3         950       0.1
# 3   INV-349412             Training Session         3         250       0.1
# 4   INV-418746              On-Site Support         3         500       0.1
# 5   INV-418746              On-Site Support         2         500       0.1
# 6   INV-376222             Training Session         3         250       0.1
# 7   INV-376222             Maintenance Plan         2         300       0.1
# 8   INV-780647  Brand Strategy Consultation         2         950       0.1
# 9   INV-780647             Training Session         2         250       0.1
# 10  INV-780647              On-Site Support         1         500       0.1
# 11  INV-207628              SSL Certificate         2          75       0.1
# 12  INV-207628      IT Infrastructure Setup         2        2000       0.1
# 13  INV-207628              On-Site Support         1         500       0.1
# 14  INV-207628             Maintenance Plan         2         300       0.1
# 15  INV-207628  Brand Strategy Consultation         1         950       0.1
# 16  INV-407239  Brand Strategy Consultation         1         950       0.1
# 17  INV-407239  Brand Strategy Consultation         2         950       0.1
# 18  INV-407239             Training Session         1         250       0.1
# 19  INV-407239              On-Site Support         3         500       0.1
# 20  INV-641749  Brand Strategy Consultation         1         950       0.1
# 21  INV-641749              Web Development         2        1200       0.1
# 22  INV-641749  Brand Strategy Consultation         3         950       0.1
# 23  INV-641749              On-Site Support         1         500       0.1
# 24  INV-641749      IT Infrastructure Setup         2        2000       0.1
# 25  INV-523329  Brand Strategy Consultation         3         950       0.1
# 26  INV-523329             Maintenance Plan         3         300       0.1
# 27  INV-523329             Training Session         1         250       0.1
# 28  INV-694651              On-Site Support         2         500       0.1
# 29  INV-694651                  Logo Design         3         600       0.1
# 30  INV-694651      IT Infrastructure Setup         2        2000       0.1
# 31  INV-694651      IT Infrastructure Setup         1        2000       0.1
#
#     discount
# 0      10.14
# 1       9.75
# 2       2.99
# 3       2.05
# 4       5.22
# 5       9.60
# 6       4.91
# 7      14.62
# 8       7.02
# 9       0.00
# 10     14.56
# 11      3.14
# 12      8.25
# 13      2.07
# 14     12.06
# 15      9.26
# 16      5.76
# 17      0.26
# 18      5.82
# 19      0.19
# 20      9.19
# 21      1.06
# 22     13.85
# 23      9.98
# 24      6.87
# 25      3.17
# 26      3.66
# 27     14.62
# 28      8.58
# 29     14.44
# 30      8.83
# 31      5.51
# Dataset saved to orders.csv
