# %%
from typing import List, Dict
from faker import Faker
import pandas as pd
import random

fake = Faker()
PRODUCTS = [
    'Web Development', 'Maintenance Plan', 'SSL Certificate',
    'Brand Strategy Consultation', 'Logo Design', 
    'IT Infrastructure Setup', 'On-Site Support', 'Training Session'
]

UNIT_PRICES = {
    'Web Development': 1200, 
    'Maintenance Plan': 300,
    'SSL Certificate': 75, 
    'Brand Strategy Consultation': 950,
    'Logo Design': 600, 
    'IT Infrastructure Setup': 2000,
    'On-Site Support': 500, 
    'Training Session': 250  
}

DEFAULT_TAX_RATE = 0.1  # 10% tax

def generate_customer_info() -> Dict:
    name = fake.name()
    return {
        'name': name,
        'email': f"{name.replace(' ', '').lower()}@gmail.com",
        'phone': fake.phone_number(),
        'address': fake.address().replace('\n', ', ')
    }

def generate_order_items(customer_name: str, num_items: int) -> List[Dict]:
    items = []
    cart_id = f"INV-{random.randint(100000, 999999)}"
    
    for _ in range(num_items):
        product = random.choice(PRODUCTS)
        quantity = random.randint(1, 3)
        unit_price = UNIT_PRICES[product]
        discount = round(random.uniform(0, 15), 2)  # Discount between 0% and 15%
        
        items.append({
            'cart_id': cart_id,
            'product_description': product,
            'quantity': quantity,
            'unit_price': unit_price,
            'tax_rate': DEFAULT_TAX_RATE,
            'discount': discount
        })
    
    return items

def generate_dataset(number_of_customers: int = 10, min_items: int = 1, max_items: int = 5) -> pd.DataFrame:
    data = []
    
    for _ in range(number_of_customers):
        customer = generate_customer_info()
        order_items = generate_order_items(
            customer['name'],
            random.randint(min_items, max_items)
        )
        
        for item in order_items:
            record = {
                'customer_name': customer['name'],
                'customer_email': customer['email'],
                'customer_phone': customer['phone'],
                'customer_address': customer['address'],
                **item
            }
            data.append(record)
    
    return pd.DataFrame(data)

if __name__ == "__main__":
    df = generate_dataset(number_of_customers=10, min_items=1, max_items=5)
    df.to_csv('orders.csv', index=False)
    display(df)
# Out:
#                 customer_name                    customer_email  \
# 0             Natasha Bennett          natashabennett@gmail.com
# 1             Natasha Bennett          natashabennett@gmail.com
# 2             Natasha Bennett          natashabennett@gmail.com
# 3             Natasha Bennett          natashabennett@gmail.com
# 4                   Ryan Ford                ryanford@gmail.com
# 5                   Ryan Ford                ryanford@gmail.com
# 6                   Ryan Ford                ryanford@gmail.com
# 7                   Ryan Ford                ryanford@gmail.com
# 8                 Jesse Smith              jessesmith@gmail.com
# 9                 Jesse Smith              jessesmith@gmail.com
# 10                Jesse Smith              jessesmith@gmail.com
# 11                Jesse Smith              jessesmith@gmail.com
# 12               Taylor Quinn             taylorquinn@gmail.com
# 13               Taylor Quinn             taylorquinn@gmail.com
# 14               Taylor Quinn             taylorquinn@gmail.com
# 15  Mr. Mitchell Davidson Jr.  mr.mitchelldavidsonjr.@gmail.com
# 16             Michael Morgan           michaelmorgan@gmail.com
# 17             Michael Morgan           michaelmorgan@gmail.com
# 18                 Bryan Reed               bryanreed@gmail.com
# 19              Jennifer Dunn            jenniferdunn@gmail.com
# 20              Jennifer Dunn            jenniferdunn@gmail.com
# 21              Jennifer Dunn            jenniferdunn@gmail.com
# 22                 John Morse               johnmorse@gmail.com
# 23                 John Morse               johnmorse@gmail.com
# 24               Ronald Stone             ronaldstone@gmail.com
# 25               Ronald Stone             ronaldstone@gmail.com
# 26               Ronald Stone             ronaldstone@gmail.com
#
#             customer_phone                                   customer_address  \
# 0        (839)677-7190x683          153 Castaneda Village, Johnstad, MS 46008
# 1        (839)677-7190x683          153 Castaneda Village, Johnstad, MS 46008
# 2        (839)677-7190x683          153 Castaneda Village, Johnstad, MS 46008
# 3        (839)677-7190x683          153 Castaneda Village, Johnstad, MS 46008
# 4       847-419-1183x39355     306 Atkins Rapids, North Vincentbury, OH 82065
# 5       847-419-1183x39355     306 Atkins Rapids, North Vincentbury, OH 82065
# 6       847-419-1183x39355     306 Atkins Rapids, North Vincentbury, OH 82065
# 7       847-419-1183x39355     306 Atkins Rapids, North Vincentbury, OH 82065
# 8   001-895-429-8143x47912    5181 Ronald Vista, South Williamville, NH 27596
# 9   001-895-429-8143x47912    5181 Ronald Vista, South Williamville, NH 27596
# 10  001-895-429-8143x47912    5181 Ronald Vista, South Williamville, NH 27596
# 11  001-895-429-8143x47912    5181 Ronald Vista, South Williamville, NH 27596
# 12        330-704-2962x105  482 Scott Rapid Suite 337, South Christopher, ...
# 13        330-704-2962x105  482 Scott Rapid Suite 337, South Christopher, ...
# 14        330-704-2962x105  482 Scott Rapid Suite 337, South Christopher, ...
# 15      (615)565-2474x3194      8941 Clark Cove Apt. 548, Whiteview, MI 36025
# 16   001-548-437-1269x5416                       USCGC Castillo, FPO AE 62005
# 17   001-548-437-1269x5416                       USCGC Castillo, FPO AE 62005
# 18       581.344.2668x7455  21988 Nelson Mall Suite 593, Katherinechester,...
# 19       381-510-7530x0910  33242 Michael View Suite 066, North Eddie, AS ...
# 20       381-510-7530x0910  33242 Michael View Suite 066, North Eddie, AS ...
# 21       381-510-7530x0910  33242 Michael View Suite 066, North Eddie, AS ...
# 22      777.787.9646x67323   1730 Tracy Forges Apt. 977, Brianmouth, MA 61240
# 23      777.787.9646x67323   1730 Tracy Forges Apt. 977, Brianmouth, MA 61240
# 24     +1-821-503-6411x848                   Unit 7837 Box 9475, DPO AA 59860
# 25     +1-821-503-6411x848                   Unit 7837 Box 9475, DPO AA 59860
# 26     +1-821-503-6411x848                   Unit 7837 Box 9475, DPO AA 59860
#
#        cart_id          product_description  quantity  unit_price  tax_rate  \
# 0   INV-673880              On-Site Support         3         500       0.1
# 1   INV-673880              Web Development         2        1200       0.1
# 2   INV-673880             Maintenance Plan         2         300       0.1
# 3   INV-673880              On-Site Support         2         500       0.1
# 4   INV-360900              On-Site Support         3         500       0.1
# 5   INV-360900             Maintenance Plan         3         300       0.1
# 6   INV-360900              On-Site Support         2         500       0.1
# 7   INV-360900             Maintenance Plan         2         300       0.1
# 8   INV-842314      IT Infrastructure Setup         3        2000       0.1
# 9   INV-842314  Brand Strategy Consultation         3         950       0.1
# 10  INV-842314              SSL Certificate         2          75       0.1
# 11  INV-842314             Maintenance Plan         1         300       0.1
# 12  INV-789228              On-Site Support         2         500       0.1
# 13  INV-789228                  Logo Design         3         600       0.1
# 14  INV-789228             Training Session         3         250       0.1
# 15  INV-803682              SSL Certificate         1          75       0.1
# 16  INV-117471             Maintenance Plan         3         300       0.1
# 17  INV-117471              Web Development         3        1200       0.1
# 18  INV-531654             Training Session         1         250       0.1
# 19  INV-995318             Maintenance Plan         2         300       0.1
# 20  INV-995318                  Logo Design         1         600       0.1
# 21  INV-995318              SSL Certificate         3          75       0.1
# 22  INV-691737             Maintenance Plan         2         300       0.1
# 23  INV-691737                  Logo Design         1         600       0.1
# 24  INV-428018      IT Infrastructure Setup         1        2000       0.1
# 25  INV-428018      IT Infrastructure Setup         3        2000       0.1
# 26  INV-428018                  Logo Design         2         600       0.1
#
#     discount
# 0      12.67
# 1      11.40
# 2       7.24
# 3      12.42
# 4      11.04
# 5      11.76
# 6      10.66
# 7       5.10
# 8       7.58
# 9       6.48
# 10      7.97
# 11      8.73
# 12      2.88
# 13      3.74
# 14      7.67
# 15     12.95
# 16      4.09
# 17     14.27
# 18      5.77
# 19     13.93
# 20      1.63
# 21      8.19
# 22      5.05
# 23     11.69
# 24      3.36
# 25      7.34
# 26      6.27
